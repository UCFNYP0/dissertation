# %%
import pandas as pd
import numpy as np
import geopandas as gpd
import networkx as nx
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
import json
import re
from shapely.geometry import Point, LineString #this library is for manipulating geometric objects, and it is what geopandas uses to store geometries
from scipy.spatial import distance

# %%
df = pd.read_csv('dataset_new.csv')

# %%
df.columns
# Out:
# Index(['Start.date', 'Start.station', 'End.date', 'End.station', 'id', 'lon',
#        'lat'],
#       dtype='object')

# %%
#covert the listing to the geo dataframe
g_df = gpd.GeoDataFrame(df, geometry=gpd.points_from_xy(df.lon, df.lat), crs='epsg:27700')
g_df.crs
# Out:
# <Derived Projected CRS: EPSG:27700>
# Name: OSGB36 / British National Grid
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: United Kingdom (UK) - offshore to boundary of UKCS within 49°45'N to 61°N and 9°W to 2°E; onshore Great Britain (England, Wales and Scotland). Isle of Man onshore.
# - bounds: (-9.0, 49.75, 2.01, 61.01)
# Coordinate Operation:
# - name: British National Grid
# - method: Transverse Mercator
# Datum: Ordnance Survey of Great Britain 1936
# - Ellipsoid: Airy 1830
# - Prime Meridian: Greenwich

# %%
g_df.head()
# Out:
#         Start.date                    Start.station         End.date  \
# 0  2023/3/31 23:57         Vauxhall Cross, Vauxhall  2023/3/31 23:58
# 1  2023/3/31 23:54    Ossulston Street, Somers Town  2023/3/31 23:56
# 2  2023/3/31 23:54  Parson's Green , Parson's Green  2023/3/31 23:58
# 3  2023/3/31 23:52  Westfield Ariel Way, White City  2023/3/31 23:59
# 4  2023/3/31 23:52        Berry Street, Clerkenwell  2023/3/31 23:59
#
#                              End.station              id       lon        lat  \
# 0  Kennington Lane Rail Bridge, Vauxhall   BikePoints_74 -0.124469  51.485917
# 1                Doric Way , Somers Town  BikePoints_797 -0.128279  51.529300
# 2                  Elysium Place, Fulham  BikePoints_596 -0.199783  51.472817
# 3      St. Mark's Road, North Kensington  BikePoints_566 -0.224103  51.509158
# 4                   Queen Street 1, Bank  BikePoints_246 -0.099994  51.522853
#
#                 geometry
# 0  POINT (-0.124 51.486)
# 1  POINT (-0.128 51.529)
# 2  POINT (-0.200 51.473)
# 3  POINT (-0.224 51.509)
# 4  POINT (-0.100 51.523)

# %%
# Convert the Start.date and End.date to datetime format
g_df['Start.date'] = pd.to_datetime(g_df['Start.date'])
g_df['End.date'] = pd.to_datetime(g_df['End.date'])

# Set the time period
start_time = "07:00:00"
end_time = "09:00:00"

# %%
g_df
# Out:
#                 Start.date                    Start.station  \
# 0      2023-03-31 23:57:00         Vauxhall Cross, Vauxhall
# 1      2023-03-31 23:54:00    Ossulston Street, Somers Town
# 2      2023-03-31 23:54:00  Parson's Green , Parson's Green
# 3      2023-03-31 23:52:00  Westfield Ariel Way, White City
# 4      2023-03-31 23:52:00        Berry Street, Clerkenwell
# ...                    ...                              ...
# 575350 2023-03-20 00:03:00  Earnshaw Street , Covent Garden
# 575351 2023-03-20 00:02:00              Euston Road, Euston
# 575352 2023-03-20 00:01:00         Malet Street, Bloomsbury
# 575353 2023-03-20 00:00:00        Tooley Street, Bermondsey
# 575354 2023-03-20 00:00:00   Kensington Gore, Knightsbridge
#
#                   End.date                            End.station  \
# 0      2023-03-31 23:58:00  Kennington Lane Rail Bridge, Vauxhall
# 1      2023-03-31 23:56:00                Doric Way , Somers Town
# 2      2023-03-31 23:58:00                  Elysium Place, Fulham
# 3      2023-03-31 23:59:00      St. Mark's Road, North Kensington
# 4      2023-03-31 23:59:00                   Queen Street 1, Bank
# ...                    ...                                    ...
# 575350 2023-03-20 00:39:00                Bow Church Station, Bow
# 575351 2023-03-20 00:21:00      Great Suffolk Street, The Borough
# 575352 2023-03-20 00:17:00           Northington Street , Holborn
# 575353 2023-03-20 00:33:00             Empire Square, The Borough
# 575354 2023-03-20 00:08:00           Southwick Street, Paddington
#
#                     id       lon        lat               geometry
# 0        BikePoints_74 -0.124469  51.485917  POINT (-0.124 51.486)
# 1       BikePoints_797 -0.128279  51.529300  POINT (-0.128 51.529)
# 2       BikePoints_596 -0.199783  51.472817  POINT (-0.200 51.473)
# 3       BikePoints_566 -0.224103  51.509158  POINT (-0.224 51.509)
# 4       BikePoints_246 -0.099994  51.522853  POINT (-0.100 51.523)
# ...                ...       ...        ...                    ...
# 575350  BikePoints_244 -0.128585  51.516118  POINT (-0.129 51.516)
# 575351   BikePoints_69 -0.134407  51.526236  POINT (-0.134 51.526)
# 575352   BikePoints_12 -0.130431  51.521680  POINT (-0.130 51.522)
# 575353  BikePoints_278 -0.079620  51.503493  POINT (-0.080 51.503)
# 575354  BikePoints_258 -0.178656  51.501432  POINT (-0.179 51.501)
#
# [575355 rows x 8 columns]

# %%
# Filter the dataset for rides between 07:00 and 09:00 during the period 17-23 October 2022
filtered_df = g_df[(g_df['Start.date'].dt.time >= pd.to_datetime(start_time).time()) &
                     (g_df['End.date'].dt.time <= pd.to_datetime(end_time).time()) &
                     (g_df['Start.date'].dt.date >= pd.to_datetime("2023-03-01").date()) &
                     (g_df['End.date'].dt.date <= pd.to_datetime("2023-03-31").date())]

# %%
filtered_df
# Out:
#                 Start.date                    Start.station  \
# 8308   2023-03-31 08:59:00       Empire Square, The Borough
# 8342   2023-03-31 08:57:00     Northington Street , Holborn
# 8345   2023-03-31 08:58:00      Newgate Street , St. Paul's
# 8346   2023-03-31 08:58:00   Clerkenwell Green, Clerkenwell
# 8349   2023-03-31 08:57:00  Sadlers Sports Centre, Finsbury
# ...                    ...                              ...
# 574310 2023-03-20 07:00:00      Newgate Street , St. Paul's
# 574311 2023-03-20 07:00:00        Smugglers Way, Wandsworth
# 574312 2023-03-20 07:00:00         Swan Street, The Borough
# 574325 2023-03-20 07:00:00      Arlington Road, Camden Town
# 574326 2023-03-20 07:00:00        Breams Buildings, Holborn
#
#                   End.date                        End.station              id  \
# 8308   2023-03-31 09:00:00   Borough High Street, The Borough  BikePoints_269
# 8342   2023-03-31 09:00:00           Red Lion Street, Holborn   BikePoints_22
# 8345   2023-03-31 09:00:00           New Fetter Lane, Holborn   BikePoints_71
# 8346   2023-03-31 09:00:00          St. John Street, Finsbury  BikePoints_135
# 8349   2023-03-31 09:00:00              Bunhill Row, Moorgate   BikePoints_78
# ...                    ...                                ...             ...
# 574310 2023-03-20 07:08:00           Swan Street, The Borough   BikePoints_71
# 574311 2023-03-20 07:01:00          Smugglers Way, Wandsworth  BikePoints_665
# 574312 2023-03-20 07:05:00          Strata, Elephant & Castle  BikePoints_295
# 574325 2023-03-20 07:28:00             Fore Street, Guildhall  BikePoints_545
# 574326 2023-03-20 07:22:00  Wormwood Street, Liverpool Street   BikePoints_84
#
#              lon        lat               geometry
# 8308   -0.089740  51.500823  POINT (-0.090 51.501)
# 8342   -0.114079  51.522264  POINT (-0.114 51.522)
# 8345   -0.098850  51.515418  POINT (-0.099 51.515)
# 8346   -0.104708  51.523260  POINT (-0.105 51.523)
# 8349   -0.099489  51.524868  POINT (-0.099 51.525)
# ...          ...        ...                    ...
# 574310 -0.098850  51.515418  POINT (-0.099 51.515)
# 574311 -0.191722  51.461083  POINT (-0.192 51.461)
# 574312 -0.092762  51.500296  POINT (-0.093 51.500)
# 574325 -0.145246  51.539957  POINT (-0.145 51.540)
# 574326 -0.111778  51.515937  POINT (-0.112 51.516)
#
# [85220 rows x 8 columns]

# %%
columns = ['Start.station','End.station','geometry']
filtered_df= filtered_df[columns]
filtered_df
# Out:
#                           Start.station                        End.station  \
# 8308         Empire Square, The Borough   Borough High Street, The Borough
# 8342       Northington Street , Holborn           Red Lion Street, Holborn
# 8345        Newgate Street , St. Paul's           New Fetter Lane, Holborn
# 8346     Clerkenwell Green, Clerkenwell          St. John Street, Finsbury
# 8349    Sadlers Sports Centre, Finsbury              Bunhill Row, Moorgate
# ...                                 ...                                ...
# 574310      Newgate Street , St. Paul's           Swan Street, The Borough
# 574311        Smugglers Way, Wandsworth          Smugglers Way, Wandsworth
# 574312         Swan Street, The Borough          Strata, Elephant & Castle
# 574325      Arlington Road, Camden Town             Fore Street, Guildhall
# 574326        Breams Buildings, Holborn  Wormwood Street, Liverpool Street
#
#                      geometry
# 8308    POINT (-0.090 51.501)
# 8342    POINT (-0.114 51.522)
# 8345    POINT (-0.099 51.515)
# 8346    POINT (-0.105 51.523)
# 8349    POINT (-0.099 51.525)
# ...                       ...
# 574310  POINT (-0.099 51.515)
# 574311  POINT (-0.192 51.461)
# 574312  POINT (-0.093 51.500)
# 574325  POINT (-0.145 51.540)
# 574326  POINT (-0.112 51.516)
#
# [85220 rows x 3 columns]

# %%
# Suppose filtered_df is a filtered version of the original dataframe df
filtered_df1 = filtered_df.copy()

# Now you can modify filtered_df without warnings
filtered_df1['Route'] = filtered_df1['Start.station'] + ' - ' + filtered_df1['End.station']
df_route_counts = filtered_df1.groupby('Route').size().reset_index(name='Counts')
df_route_counts = df_route_counts.sort_values('Counts', ascending=False)

# %%
df_route_counts[['Start.station', 'End.station']] = df_route_counts['Route'].str.split(' - ', expand=True)

# %%
df_route_counts
# Out:
#                                                    Route  Counts  \
# 140         Ackroyd Drive, Bow - Maplin Street, Mile End      98
# 30662  Waterloo Station 3, Waterloo - Newgate Street ...      85
# 22820  Rainville Road, Hammersmith - Barons Court Sta...      77
# 30659  Waterloo Station 3, Waterloo - New Fetter Lane...      70
# 30554     Waterloo Station 3, Waterloo - Cheapside, Bank      68
# ...                                                  ...     ...
# 19049  Nantes Close, Wandsworth - St. John's Road, Cl...       1
# 19048  Nantes Close, Wandsworth - St Mary's Hospital,...       1
# 19047   Nantes Close, Wandsworth - South Park, Sands End       1
# 7719   Crimscott Street, Bermondsey - Braham Street, ...       1
# 0      Abbey Orchard Street, Westminster - Ashley Pla...       1
#
#                            Start.station  \
# 140                   Ackroyd Drive, Bow
# 30662       Waterloo Station 3, Waterloo
# 22820        Rainville Road, Hammersmith
# 30659       Waterloo Station 3, Waterloo
# 30554       Waterloo Station 3, Waterloo
# ...                                  ...
# 19049           Nantes Close, Wandsworth
# 19048           Nantes Close, Wandsworth
# 19047           Nantes Close, Wandsworth
# 7719        Crimscott Street, Bermondsey
# 0      Abbey Orchard Street, Westminster
#
#                                  End.station
# 140                  Maplin Street, Mile End
# 30662            Newgate Street , St. Paul's
# 22820  Barons Court Station, West Kensington
# 30659               New Fetter Lane, Holborn
# 30554                        Cheapside, Bank
# ...                                      ...
# 19049      St. John's Road, Clapham Junction
# 19048         St Mary's Hospital, Paddington
# 19047                  South Park, Sands End
# 7719                  Braham Street, Aldgate
# 0                     Ashley Place, Victoria
#
# [32305 rows x 4 columns]

# %%
df_route_counts.to_csv('output_new.csv', index=False)
